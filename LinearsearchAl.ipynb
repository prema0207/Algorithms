# %% [markdown]
# <a href="https://colab.research.google.com/github/prema0207/Algorithms/blob/main/LinearsearchAl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
import random
import matplotlib.pyplot as plt
def linear_search(arr, target):
    for i in range(len(arr)):
        if arr[i] == target:
            return i
    return -1
list_sizes = []
times_taken=[]
for n in range(1000, 11000, 1000):
    arr = list(range(n))
    target = -1
    start_time = time.time()
    linear_search(arr, target)
    end_time = time.time()

    time_taken = end_time - start_time
    list_sizes.append(n)
    times_taken.append(time_taken)
plt.figure(figsize=(10, 6))
plt.plot(list_sizes, times_taken, marker='o', color='blue')
plt.title("Linear Search Time vs. List Size")
plt.xlabel("Number of Elements (n)")
plt.ylabel("Time Taken (seconds)")
plt.grid(True)
plt.show()
